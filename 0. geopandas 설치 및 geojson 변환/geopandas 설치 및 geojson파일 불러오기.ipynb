# %%
import geopandas as gpd
import pandas
from shapely.geometry import Point

# %%
# !pip install folium
import folium

# %%
data=gpd.read_file("C:/Users/Kim Won Gyeung/Desktop/공모전/2021 빅데이터 분석 및 아이디어 공모전/2.사용_데이터/1.QGIS에 사용할 데이터(gid 가능데이터)/lpglocation.geojson")
data1 = gpd.read_file("C:/Users/Kim Won Gyeung/Desktop/공모전/2021 빅데이터 분석 및 아이디어 공모전/2.사용_데이터/1.QGIS에 사용할 데이터(gid 가능데이터)/new lpglocation.geojson")

# %%
data.iloc[17,1]
data.iloc[17.2]
data.iloc[17,3] = Point(127.477793,36.267718)
# Out:
# 127.4777934

# %%
data
# Out:
#                   소재지   Latitude   Longitude                    geometry
# 0    대전 대덕구 상서동 441-3  36.422211  127.419109  POINT (127.41911 36.42221)
# 1   대전 대덕구 대화동 16-140  36.364771  127.418928  POINT (127.41893 36.36477)
# 2      대전 대덕구 대화동 3-1  36.368744  127.418945  POINT (127.41895 36.36874)
# 3   대전 대덕구 상서동 349-12  36.425293  127.420454  POINT (127.42045 36.42529)
# 4      대전 대덕구 상서동 440  36.422242  127.419851  POINT (127.41985 36.42224)
# 5    대전 대덕구 평촌동 226-5  36.436035  127.425928  POINT (127.42593 36.43603)
# 6    대전 대덕구 신대동 433-2  36.391156  127.412595  POINT (127.41260 36.39116)
# 7   대전 대덕구 대화동 549-16  36.364396  127.399804  POINT (127.39980 36.36440)
# 8      대전 대덕구 읍내동 511  36.376881  127.412609  POINT (127.41261 36.37688)
# 9   대전 대덕구 신일동 1684-1  36.445569  127.406309  POINT (127.40631 36.44557)
# 10   대전 대덕구 연축동 294-2  36.387368  127.422561  POINT (127.42256 36.38737)
# 11   대전 대덕구 오정동 432-1  36.353130  127.415728  POINT (127.41573 36.35313)
# ...

# %%
df_geojson = gpd.GeoDataFrame(data)
df_geojson.to_file('C:/Users/Kim Won Gyeung/Desktop/공모전/2021 빅데이터 분석 및 아이디어 공모전/2.사용_데이터/1.QGIS에 사용할 데이터(gid 가능데이터)/new lpglocation.geojson', driver='GeoJSON')
